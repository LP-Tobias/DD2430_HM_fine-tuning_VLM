# %%
# !pip install peft
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: peft in /opt/conda/lib/python3.10/site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from peft) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from peft) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from peft) (2.4.0)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from peft) (4.44.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from peft) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from peft) (0.34.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from peft) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /opt/conda/lib/python3.10/site-packages (from peft) (0.25.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (2024.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->peft) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->peft) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->peft) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.0->peft) (1.3.0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
import os
from pathlib import Path
from PIL import Image
import requests
import torch
from torch.utils.data import Dataset, DataLoader
from datasets import load_dataset, Dataset
import itertools
from sklearn.model_selection import StratifiedShuffleSplit,train_test_split
from peft import LoraConfig, get_peft_model
from transformers import (
    DataCollator,
    CLIPProcessor, 
    CLIPModel, 
    TrainingArguments, 
    Trainer
)

# %%
def hf_clip_predict(model, processor, text_labels, images):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)
    text = [f"A photo of a {label}" for label in text_labels]
    inputs = processor(text=text, images=images, return_tensors="pt", padding=True).to(device)
    
    model.eval()
    with torch.no_grad():
        outputs = model(**inputs)
    
    logits_per_image = outputs.logits_per_image
    probs = logits_per_image.softmax(dim=1)
    return probs

def get_image_paths_and_labels_from_df(df, data_dir):
    article_ids = df["article_id"].values
    image_paths = []
    labels = []
    
    for article_id in article_ids:
        image_path = f"{data_dir}/images/0{str(article_id)[:2]}/0{article_id}.jpg"
        # Check if the image file exists
        if os.path.exists(image_path):
            image_paths.append(image_path)
            # Add corresponding label only if the image exists
            labels.append(df[df["article_id"] == article_id])
        else:
            print(f"Image not found for article_id: {article_id}")
    
    return image_paths, labels

def get_image_paths_and_labels_ordered(df, data_dir):
    article_ids = df["article_id"].values
    image_paths = []
    labels = []
    for article_id in article_ids:
        image_path = f"{data_dir}/images/0{str(article_id)[:2]}/0{article_id}.jpg"
        if os.path.exists(image_path):
            image_paths.append(image_path)
            labels.append(df[df["article_id"] == article_id])
    
    return image_paths, labels

def get_image_paths_and_labels(df, data_dir):
    image_paths = []
    labels = []
    for root, dirs, files in os.walk(data_dir):
        for file in files:
            if file.endswith(".jpg"):
                image_path = os.path.join(root, file)
                image_paths.append(image_path)
                article_id = int(file.split(".")[0])
                labels.append(df[df["article_id"] == article_id])

    return image_paths, labels

class ImageDataset(torch.utils.data.Dataset):
    def __init__(self, image_paths, processor=None):
        self.image_paths = image_paths
        self.processor = processor
        self.image_ids = []

        for image_path in self.image_paths:
            if not os.path.exists(image_path):
                raise FileNotFoundError(f"Image {image_path} not found.")
            else:
                image_id = int(image_path.split("/")[-1].split(".")[0])
                self.image_ids.append(image_id)
            

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx])
        if self.processor is not None:
            inputs = self.processor(images=image, return_tensors="pt", padding=True)
            image = inputs["pixel_values"][0]
        return image, self.image_ids[idx]

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
model = model.to(device)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
text_path = '/kaggle/input/h-and-m-personalized-fashion-recommendations/articles.csv'
articles = pd.read_csv(text_path)
print(articles.shape) # 100k data points
articles.head(1)
# Out:
# (105542, 25)
#    article_id  product_code  prod_name  product_type_no product_type_name  \
# 0   108775015        108775  Strap top              253          Vest top
#
#    product_group_name  graphical_appearance_no graphical_appearance_name  \
# 0  Garment Upper body                  1010016                     Solid
#
#    colour_group_code colour_group_name  ...  department_name index_code  \
# 0                  9             Black  ...     Jersey Basic          A
#
#    index_name index_group_no  index_group_name section_no  \
# 0  Ladieswear              1        Ladieswear         16
#
#              section_name garment_group_no  garment_group_name  \
# 0  Womens Everyday Basics             1002        Jersey Basic
#
#                                detail_desc
# 0  Jersey top with narrow shoulder straps.
#
# [1 rows x 25 columns]

# %%
# map from article_id to df index
article_id_to_idx = {article_id: idx for idx, article_id in enumerate(articles["article_id"])}

# get all classes of the dataframe
class_names = articles.columns.tolist()
label_names = dict()
label_names_to_idx = dict()
for class_name in class_names:
    label_names[class_name] = articles[class_name].unique()
    label_names_to_idx[class_name] = {label_name: idx for idx, label_name in enumerate(label_names[class_name])}

article_ids = label_names["article_id"]
selected_class_names = ["product_group_name", "product_type_name", "graphical_appearance_name", "colour_group_name", "perceived_colour_value_name", "perceived_colour_master_name", "department_name", "index_name", "index_group_name", "section_name", "garment_group_name"]

# %%
# get label names in product group name with less than 10 samples
product_group_name_cnts = articles["product_group_name"].value_counts()
removed_label_names = product_group_name_cnts[product_group_name_cnts < 10]

# remove data with the removed label name
removed_label_idxs = articles[articles["product_group_name"].isin(removed_label_names.index)].index
articles = articles.drop(removed_label_idxs)

# %%
data_dir = "/kaggle/input/h-and-m-personalized-fashion-recommendations"
image_paths, labels = get_image_paths_and_labels_from_df(articles, data_dir)
print(f"Number of images: {len(image_paths)}")
# Out:
# Image not found for article_id: 174057028
# Image not found for article_id: 179208001
# Image not found for article_id: 212042043
# Image not found for article_id: 212042066
# Image not found for article_id: 212629004
# Image not found for article_id: 215324023
# Image not found for article_id: 216961011
# Image not found for article_id: 218354021
# Image not found for article_id: 241602023
# Image not found for article_id: 268305006
# Image not found for article_id: 272591001
# Image not found for article_id: 324963030
# Image not found for article_id: 348657006
# Image not found for article_id: 357792006
# Image not found for article_id: 364409037
# Image not found for article_id: 369423002
# Image not found for article_id: 369423004
# Image not found for article_id: 388916001
# Image not found for article_id: 395864048
# Image not found for article_id: 396135047
# Image not found for article_id: 396135048
# Image not found for article_id: 396690010
# Image not found for article_id: 397376010
# Image not found for article_id: 398947001
# Image not found for article_id: 405310006
# Image not found for article_id: 408875001
# Image not found for article_id: 408875002
# Image not found for article_id: 408875010
# Image not found for article_id: 411565004
# Image not found for article_id: 419634007
# Image not found for article_id: 419634010
# Image not found for article_id: 419634013
# Image not found for article_id: 420264002
# Image not found for article_id: 425683012
# Image not found for article_id: 438702006
# Image not found for article_id: 442786001
# Image not found for article_id: 443262014
# Image not found for article_id: 446224011
# Image not found for article_id: 446224013
# Image not found for article_id: 453065011
# Image not found for article_id: 460363012
# Image not found for article_id: 461414009
# Image not found for article_id: 461414010
# Image not found for article_id: 468666002
# Image not found for article_id: 469039021
# Image not found for article_id: 469658014
# Image not found for article_id: 470985008
# Image not found for article_id: 470985010
# Image not found for article_id: 475791011
# Image not found for article_id: 475827007
# Image not found for article_id: 480076004
# Image not found for article_id: 481777003
# Image not found for article_id: 481797022
# Image not found for article_id: 481797026
# Image not found for article_id: 481797027
# Image not found for article_id: 484864002
# Image not found for article_id: 485673022
# Image not found for article_id: 485678030
# Image not found for article_id: 485678032
# Image not found for article_id: 485973011
# Image not found for article_id: 486639004
# Image not found for article_id: 487926002
# Image not found for article_id: 489758004
# Image not found for article_id: 490275001
# Image not found for article_id: 490473012
# Image not found for article_id: 491912034
# Image not found for article_id: 494030013
# Image not found for article_id: 496762004
# Image not found for article_id: 499802028
# Image not found for article_id: 504152001
# Image not found for article_id: 504152008
# Image not found for article_id: 504960001
# Image not found for article_id: 504960003
# Image not found for article_id: 506177002
# Image not found for article_id: 507399003
# Image not found for article_id: 508931033
# Image not found for article_id: 510415003
# Image not found for article_id: 510504001
# Image not found for article_id: 511653001
# Image not found for article_id: 512300003
# Image not found for article_id: 512964002
# Image not found for article_id: 513701002
# Image not found for article_id: 515074002
# Image not found for article_id: 516550001
# Image not found for article_id: 516898002
# Image not found for article_id: 517724002
# Image not found for article_id: 517729011
# Image not found for article_id: 517729015
# Image not found for article_id: 517729030
# Image not found for article_id: 519219008
# Image not found for article_id: 519815003
# Image not found for article_id: 519987002
# Image not found for article_id: 520363002
# Image not found for article_id: 521272004
# Image not found for article_id: 521393002
# Image not found for article_id: 522725001
# Image not found for article_id: 523518001
# Image not found for article_id: 525111001
# Image not found for article_id: 525460003
# Image not found for article_id: 527210001
# Image not found for article_id: 527383001
# Image not found for article_id: 528269002
# Image not found for article_id: 528466001
# Image not found for article_id: 528931003
# Image not found for article_id: 530106001
# Image not found for article_id: 530106002
# Image not found for article_id: 532227001
# Image not found for article_id: 532227002
# Image not found for article_id: 532698001
# Image not found for article_id: 532885001
# Image not found for article_id: 532956001
# Image not found for article_id: 532956002
# Image not found for article_id: 533639001
# Image not found for article_id: 533639002
# Image not found for article_id: 533676006
# Image not found for article_id: 536310001
# Image not found for article_id: 537732001
# Image not found for article_id: 538358010
# Image not found for article_id: 538923001
# Image not found for article_id: 539724003
# Image not found for article_id: 539844003
# Image not found for article_id: 541512005
# Image not found for article_id: 541519005
# Image not found for article_id: 542209002
# Image not found for article_id: 543593001
# Image not found for article_id: 544866001
# Image not found for article_id: 545706001
# Image not found for article_id: 546128001
# Image not found for article_id: 546141003
# Image not found for article_id: 546269002
# Image not found for article_id: 546520001
# Image not found for article_id: 546520002
# Image not found for article_id: 546733001
# Image not found for article_id: 546773003
# Image not found for article_id: 548757002
# Image not found for article_id: 549758001
# Image not found for article_id: 549978001
# Image not found for article_id: 549978007
# Image not found for article_id: 550562002
# Image not found for article_id: 551718002
# Image not found for article_id: 552279001
# Image not found for article_id: 552471003
# Image not found for article_id: 552979001
# Image not found for article_id: 553023001
# Image not found for article_id: 554811016
# Image not found for article_id: 554811018
# Image not found for article_id: 554811019
# Image not found for article_id: 554952001
# Image not found for article_id: 555297001
# Image not found for article_id: 556493001
# Image not found for article_id: 556493002
# Image not found for article_id: 556493005
# Image not found for article_id: 556493010
# Image not found for article_id: 556497002
# Image not found for article_id: 556497010
# Image not found for article_id: 557035002
# Image not found for article_id: 557080001
# Image not found for article_id: 558355001
# Image not found for article_id: 558402003
# Image not found for article_id: 558651001
# Image not found for article_id: 558651003
# Image not found for article_id: 558680001
# Image not found for article_id: 558706001
# Image not found for article_id: 559529001
# Image not found for article_id: 559646002
# Image not found for article_id: 560783009
# Image not found for article_id: 560783010
# Image not found for article_id: 561303001
# Image not found for article_id: 561746001
# Image not found for article_id: 562152001
# Image not found for article_id: 562152005
# Image not found for article_id: 562162001
# Image not found for article_id: 562298002
# Image not found for article_id: 562328001
# Image not found for article_id: 562328002
# Image not found for article_id: 562612002
# Image not found for article_id: 562612003
# Image not found for article_id: 562748001
# Image not found for article_id: 562900002
# Image not found for article_id: 562900008
# Image not found for article_id: 563907002
# Image not found for article_id: 564069006
# Image not found for article_id: 564310002
# Image not found for article_id: 564315001
# Image not found for article_id: 564326003
# Image not found for article_id: 564373005
# Image not found for article_id: 564512006
# Image not found for article_id: 564934013
# Image not found for article_id: 565242001
# Image not found for article_id: 565481001
# Image not found for article_id: 565533001
# Image not found for article_id: 565807001
# Image not found for article_id: 565836002
# Image not found for article_id: 566288001
# Image not found for article_id: 566288002
# Image not found for article_id: 566289001
# Image not found for article_id: 566289002
# Image not found for article_id: 566432003
# Image not found for article_id: 566799005
# Image not found for article_id: 567435001
# Image not found for article_id: 567547003
# Image not found for article_id: 567721002
# Image not found for article_id: 567760006
# Image not found for article_id: 568020001
# Image not found for article_id: 568487004
# Image not found for article_id: 568623001
# Image not found for article_id: 568681001
# Image not found for article_id: 568683001
# Image not found for article_id: 568683003
# Image not found for article_id: 568684001
# Image not found for article_id: 569154001
# Image not found for article_id: 569154003
# Image not found for article_id: 569903007
# Image not found for article_id: 569930001
# Image not found for article_id: 569940001
# Image not found for article_id: 569940003
# Image not found for article_id: 570143001
# Image not found for article_id: 570144002
# Image not found for article_id: 570174001
# Image not found for article_id: 570319011
# Image not found for article_id: 571041001
# Image not found for article_id: 571442001
# Image not found for article_id: 571716001
# Image not found for article_id: 573152009
# Image not found for article_id: 573373002
# Image not found for article_id: 573373003
# Image not found for article_id: 573374002
# Image not found for article_id: 573437001
# Image not found for article_id: 574528007
# Image not found for article_id: 574528008
# Image not found for article_id: 574713001
# Image not found for article_id: 574750001
# Image not found for article_id: 574752006
# Image not found for article_id: 575004001
# Image not found for article_id: 576341001
# Image not found for article_id: 576708001
# Image not found for article_id: 576708002
# Image not found for article_id: 576812001
# Image not found for article_id: 577733001
# Image not found for article_id: 577918001
# Image not found for article_id: 578311001
# Image not found for article_id: 578319001
# Image not found for article_id: 578358001
# Image not found for article_id: 578816002
# Image not found for article_id: 578816004
# Image not found for article_id: 578834002
# Image not found for article_id: 579118002
# Image not found for article_id: 579477001
# Image not found for article_id: 580140001
# Image not found for article_id: 580475001
# Image not found for article_id: 580600006
# Image not found for article_id: 580875001
# Image not found for article_id: 581103004
# Image not found for article_id: 581162001
# Image not found for article_id: 581226001
# Image not found for article_id: 581378003
# Image not found for article_id: 581983001
# Image not found for article_id: 582210001
# Image not found for article_id: 582423002
# Image not found for article_id: 582700001
# Image not found for article_id: 583084003
# Image not found for article_id: 583120001
# Image not found for article_id: 583362001
# Image not found for article_id: 583362002
# Image not found for article_id: 583918001
# Image not found for article_id: 583983001
# Image not found for article_id: 584035003
# Image not found for article_id: 584035004
# Image not found for article_id: 584043001
# Image not found for article_id: 584043002
# Image not found for article_id: 584043003
# Image not found for article_id: 584043004
# Image not found for article_id: 584416001
# Image not found for article_id: 584601001
# Image not found for article_id: 584804001
# Image not found for article_id: 585251001
# Image not found for article_id: 585260008
# Image not found for article_id: 585580003
# Image not found for article_id: 585622001
# Image not found for article_id: 585809001
# Image not found for article_id: 585809002
# Image not found for article_id: 586362001
# Image not found for article_id: 587279001
# Image not found for article_id: 587306001
# Image not found for article_id: 587527001
# Image not found for article_id: 588096002
# Image not found for article_id: 588430002
# Image not found for article_id: 588893001
# Image not found for article_id: 589276001
# Image not found for article_id: 589428004
# Image not found for article_id: 590418001
# Image not found for article_id: 590560001
# Image not found for article_id: 591701002
# Image not found for article_id: 591836001
# Image not found for article_id: 592388001
# Image not found for article_id: 593457002
# Image not found for article_id: 593458001
# Image not found for article_id: 594104001
# Image not found for article_id: 594161001
# Image not found for article_id: 594167001
# Image not found for article_id: 594177003
# Image not found for article_id: 594453002
# Image not found for article_id: 594453003
# Image not found for article_id: 594630001
# Image not found for article_id: 594630002
# Image not found for article_id: 594678001
# Image not found for article_id: 594978003
# Image not found for article_id: 595196003
# Image not found for article_id: 595718002
# Image not found for article_id: 596097001
# Image not found for article_id: 596097002
# Image not found for article_id: 596166003
# Image not found for article_id: 596432002
# Image not found for article_id: 597420001
# Image not found for article_id: 597428001
# Image not found for article_id: 598397002
# Image not found for article_id: 598397003
# Image not found for article_id: 598908001
# Image not found for article_id: 599231002
# Image not found for article_id: 599375001
# Image not found for article_id: 599703001
# Image not found for article_id: 599703002
# Image not found for article_id: 599874001
# Image not found for article_id: 600077001
# Image not found for article_id: 600441002
# Image not found for article_id: 600920002
# Image not found for article_id: 601797001
# Image not found for article_id: 603582003
# Image not found for article_id: 603582004
# Image not found for article_id: 603583006
# Image not found for article_id: 604875002
# Image not found for article_id: 605020002
# Image not found for article_id: 605093003
# Image not found for article_id: 605130001
# Image not found for article_id: 605741001
# Image not found for article_id: 605998003
# Image not found for article_id: 606282001
# Image not found for article_id: 606301001
# Image not found for article_id: 606488002
# Image not found for article_id: 607154006
# Image not found for article_id: 607304001
# Image not found for article_id: 607390001
# Image not found for article_id: 607554001
# Image not found for article_id: 608347001
# Image not found for article_id: 608761001
# Image not found for article_id: 608903001
# Image not found for article_id: 608911001
# Image not found for article_id: 609176002
# Image not found for article_id: 609309001
# Image not found for article_id: 609335002
# Image not found for article_id: 609469001
# Image not found for article_id: 609469006
# Image not found for article_id: 609598002
# Image not found for article_id: 610107001
# Image not found for article_id: 610631002
# Image not found for article_id: 610776001
# Image not found for article_id: 610776002
# Image not found for article_id: 610927001
# Image not found for article_id: 611491002
# Image not found for article_id: 612075001
# Image not found for article_id: 612075002
# Image not found for article_id: 612075004
# Image not found for article_id: 612277001
# Image not found for article_id: 613274001
# Image not found for article_id: 615508001
# Image not found for article_id: 616049001
# Image not found for article_id: 616606001
# Image not found for article_id: 616626001
# Image not found for article_id: 616635002
# Image not found for article_id: 616808001
# Image not found for article_id: 617534007
# Image not found for article_id: 618160001
# Image not found for article_id: 618160002
# Image not found for article_id: 619190001
# Image not found for article_id: 619499003
# Image not found for article_id: 619739054
# Image not found for article_id: 620208073
# Image not found for article_id: 620319007
# Image not found for article_id: 620319011
# Image not found for article_id: 620337002
# Image not found for article_id: 620585007
# Image not found for article_id: 620754001
# Image not found for article_id: 620754004
# Image not found for article_id: 622220002
# Image not found for article_id: 622233001
# Image not found for article_id: 623245002
# Image not found for article_id: 623266001
# Image not found for article_id: 623498001
# Image not found for article_id: 623935001
# Image not found for article_id: 624692003
# Image not found for article_id: 626263002
# Image not found for article_id: 629381001
# Image not found for article_id: 629381002
# Image not found for article_id: 629381004
# Image not found for article_id: 630319001
# Image not found for article_id: 630319004
# Image not found for article_id: 630324001
# Image not found for article_id: 630326003
# Image not found for article_id: 630326004
# Image not found for article_id: 632642003
# Image not found for article_id: 634160002
# Image not found for article_id: 634160004
# Image not found for article_id: 639404001
# Image not found for article_id: 639410001
# Image not found for article_id: 639840001
# Image not found for article_id: 639840002
# Image not found for article_id: 640330002
# Image not found for article_id: 642390001
# Image not found for article_id: 645754002
# Image not found for article_id: 648114001
# Image not found for article_id: 649597001
# Image not found for article_id: 653814001
# Image not found for article_id: 660315002
# Image not found for article_id: 667040001
# Image not found for article_id: 674606048
# Image not found for article_id: 681475006
# Image not found for article_id: 684282001
# Image not found for article_id: 691844001
# Image not found for article_id: 699923092
# Image not found for article_id: 699923104
# Image not found for article_id: 711727001
# Image not found for article_id: 733896001
# Image not found for article_id: 745005001
# Image not found for article_id: 753017001
# Image not found for article_id: 754792003
# Image not found for article_id: 763988002
# Image not found for article_id: 778064045
# Image not found for article_id: 781135001
# Image not found for article_id: 788632002
# Image not found for article_id: 797075003
# Image not found for article_id: 803593009
# Image not found for article_id: 806139001
# Image not found for article_id: 821771001
# Image not found for article_id: 840044001
# Image not found for article_id: 863646002
# Image not found for article_id: 868230019
# Image not found for article_id: 870501001
# Image not found for article_id: 877369001
# Image not found for article_id: 880333001
# Image not found for article_id: 901588001
# Image not found for article_id: 903309002
# Image not found for article_id: 915362001
# Number of images: 105081

# %%
# strafity with product_group_name
product_group_name = [label["product_group_name"] for label in labels]
# split 0.6/0.2/0.2
train_image_paths, test_image_paths, train_labels, test_labels = train_test_split(
    image_paths, product_group_name, stratify=product_group_name, test_size=0.4, random_state=42)
val_image_paths, test_image_paths, val_labels, test_labels = train_test_split(
    test_image_paths, test_labels, stratify=test_labels, test_size=0.5, random_state=42)

# %%
# Define LoRA configuration
lora_config = LoraConfig(
    r=8,                  # Low-rank dimension (adjustable)
    lora_alpha=32,          # Scaling factor (adjustable)
    target_modules=["q_proj", "v_proj", "k_proj"],  # Specify which layers to apply LoRA to
    lora_dropout=0.05,       # Dropout rate (optional)
    bias="none",            # Whether to include biases ("none", "all", "lora_only")
    task_type="classification"  # Task type ("classification" or "regression")
)

# Apply LoRA to the CLIP model
model = get_peft_model(model, lora_config)

# %%
train_dataset = ImageDataset(train_image_paths, processor)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=256, shuffle=True)

val_dataset = ImageDataset(val_image_paths, processor)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=256, shuffle=False)

test_dataset = ImageDataset(test_image_paths, processor)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=256, shuffle=False)

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
criteria = torch.nn.CrossEntropyLoss()

model.to(device)

class_name = "product_group_name"

# print trainable parameters
#for name, param in model.named_parameters():
#    if param.requires_grad:
#        print(name)

# %%
def validate(model, dataloader, criteria, device, text_inputs, class_name):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    with torch.no_grad():
        for images, image_ids in dataloader:
            images = images.to(device)

            # Get true labels from image_ids
            true_labels = [label_names_to_idx[class_name][articles.loc[article_id_to_idx[image_id.item()], class_name]] 
                       for image_id in image_ids]
            true_labels = torch.tensor(true_labels).to(device)

            # Forward pass
            outputs = model(**text_inputs, pixel_values=images)
            logits_per_image = outputs.logits_per_image

            # Compute loss
            loss = criteria(logits_per_image, true_labels)
            total_loss += loss.item() * images.size(0)

            # Predictions and accuracy
            _, preds = torch.max(logits_per_image, dim=1)
            total_correct += (preds == true_labels).sum().item()
            total_samples += images.size(0)

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    return avg_loss, accuracy

# %%
# Prepare text inputs once
text_inputs = processor(
    text=[f"A photo of a {label}" for label in label_names[class_name]],
    return_tensors="pt",
    padding=True
).to(device)

# %%
num_epochs = 2  # Adjust as needed
criteria = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)

for epoch in range(num_epochs):
    model.train()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    for images, image_ids in tqdm(train_dataloader):
        images = images.to(device)

        # Get true labels from image_ids
        true_labels = [label_names_to_idx[class_name][articles.loc[article_id_to_idx[image_id.item()], class_name]] 
                       for image_id in image_ids]
        true_labels = torch.tensor(true_labels).to(device)

        # Forward pass
        outputs = model(**text_inputs, pixel_values=images)
        logits_per_image = outputs.logits_per_image  # Shape: [batch_size, num_classes]
        # Do we need softmax here??

        # Compute loss
        loss = criteria(logits_per_image, true_labels)
        total_loss += loss.item() * images.size(0)

        # Predictions and accuracy
        _, preds = torch.max(logits_per_image, dim=1)
        total_correct += (preds == true_labels).sum().item()
        total_samples += images.size(0)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

    # Validate after each epoch
    val_loss, val_accuracy = validate(model, val_dataloader, criteria, device, text_inputs, class_name)
    print(f"Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}")
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]
# Epoch [1/2], Loss: 0.5275, Accuracy: 0.8406

# %%
model_save_path = 'model.pth'
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to {model_save_path}")

# %%
test_loss, test_accuracy = validate(model, test_dataloader, criteria, device, text_inputs, class_name)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# %%
"""
losses = []

for epoch in range(2):  # Change number of epochs as needed
    model.train()
    for images, image_ids in tqdm(train_dataloader):
        # Get inputs and move to the appropriate device
        images = images.to(device)
        text_inputs = processor(text=[f"A photo of a {label}" for label in label_names[class_name]], 
                                return_tensors="pt", padding=True)
        text_inputs = text_inputs.to(device)

        # Forward pass
        outputs = model(**text_inputs, pixel_values=images)

        logits_per_image = outputs.logits_per_image
        probs = logits_per_image.softmax(dim=1)

        # Get the indices of the labels
        true_labels = [label_names_to_idx[class_name][articles.loc[article_id_to_idx[image_id.item()], class_name]] 
                       for image_id in image_ids]
        true_labels = torch.tensor(true_labels)
        
        # Into one-hot encoding
        y = torch.nn.functional.one_hot(true_labels, num_classes=len(label_names[class_name]))
        
        # Convert into fp32
        y = y.float().to(device)

        loss = criteria(probs, y)
        losses.append(loss.item())

        # Optimizer step
        optimizer.zero_grad()
        loss.backward()

    print(f"Epoch {epoch + 1} completed. Loss: {loss.item()}")
    """
